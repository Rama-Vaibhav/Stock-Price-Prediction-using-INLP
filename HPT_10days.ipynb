# %%
import pandas as pd
df = pd.read_csv('merged_financial_data_news.csv')
print('CSV file loaded successfully into DataFrame named `df`.')
print(df.head())
print(df.info())
# Out:
# CSV file loaded successfully into DataFrame named `df`.
#          Date      Ticker     Open     High      Low    Close  Adj Close  \
# 0  2023-01-02    adanient  3870.00  3874.00  3822.55  3841.20    3835.94
# 1  2023-01-02  adaniports   823.00   826.75   816.30   822.30     809.38
# 2  2023-01-02  apollohosp  4488.00  4516.70  4446.00  4454.35    4411.58
# 3  2023-01-02  asianpaint  3087.90  3087.90  3021.00  3047.25    2955.81
# 4  2023-01-02    axisbank   932.25   945.00   931.80   941.60     939.11
#
#     Volume        date                                       cleaned_news  \
# 0   923051  2023-01-02  indian equity index ended monday session green...
# 1  2042294  2023-01-02  indian equity index ended monday session green...
# 2   246577  2023-01-02  indian equity index ended monday session green...
# 3  1015990  2023-01-02  indian equity index ended monday session green...
# 4  3498198  2023-01-02  indian equity index ended monday session green...
#
#    cleaned_news_len  neg_score  neu_score  pos_score
# 0             38888   0.302014    0.59563   0.102378
# 1             38888   0.302014    0.59563   0.102378
# 2             38888   0.302014    0.59563   0.102378
# 3             38888   0.302014    0.59563   0.102378
# 4             38888   0.302014    0.59563   0.102378
# <class 'pandas.DataFrame'>
# RangeIndex: 38181 entries, 0 to 38180
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              38181 non-null  str
#  1   Ticker            38181 non-null  str
#  2   Open              38181 non-null  float64
#  3   High              38181 non-null  float64
#  4   Low               38181 non-null  float64
#  5   Close             38181 non-null  float64
#  6   Adj Close         38181 non-null  float64
#  7   Volume            38181 non-null  int64
#  8   date              38181 non-null  str
#  9   cleaned_news      38181 non-null  str
#  10  cleaned_news_len  38181 non-null  int64
#  11  neg_score         38181 non-null  float64
#  12  neu_score         38181 non-null  float64
#  13  pos_score         38181 non-null  float64
# dtypes: float64(8), int64(2), str(4)
# memory usage: 4.1 MB
# None

# %%
from sklearn.preprocessing import MinMaxScaler

# Enumerate the 'Ticker' column
df['ticker_enumerated'], unique_tickers = pd.factorize(df['Ticker'])

# Scale the enumerated 'Ticker' values between 0 and 1
scaler = MinMaxScaler()
df['ticker_scaled'] = scaler.fit_transform(df[['ticker_enumerated']])

print("Enumerated Ticker values and scaled values created successfully.")
print(df[['Ticker', 'ticker_enumerated', 'ticker_scaled']].head())
# Out:
# Enumerated Ticker values and scaled values created successfully.
#        Ticker  ticker_enumerated  ticker_scaled
# 0    adanient                  0       0.000000
# 1  adaniports                  1       0.020408
# 2  apollohosp                  2       0.040816
# 3  asianpaint                  3       0.061224
# 4    axisbank                  4       0.081633

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for ticker_enumerated == 0
df_filtered = df[df['ticker_enumerated'] == 0]

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='pos_score', y='Close', data=df_filtered, alpha=0.7)
plt.title('Close Price vs. Positive Sentiment for Ticker 0')
plt.xlabel('Positive Sentiment Score')
plt.ylabel('Close Price')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Feature Engineering: Creating Lagged Features and Target Variable
#
# To predict the 11th day's closing price from 10 days of input, we need to create lagged features for each ticker. This involves shifting the data to create columns representing past values and a target column representing the future value we want to predict.

# %%
# Sort the DataFrame by Ticker and Date to ensure correct lagging
df = df.sort_values(by=['Ticker', 'Date'])

# Group by Ticker and create lagged features
features = ['Close', 'pos_score', 'neg_score', 'neu_score', 'Open', 'High', 'Low', 'Volume']

# Create lagged features for the past 10 days
for feature in features:
    for i in range(1, 11):
        df[f'{feature}_lag_{i}'] = df.groupby('Ticker')[feature].shift(i)

# Create the target variable: 'Close' price for the 11th day (shift -1)
df['target_close'] = df.groupby('Ticker')['Close'].shift(-1)

# Drop rows with NaN values resulting from lagging
df_prepared = df.dropna()

print("Lagged features and target variable created successfully.")
print(df_prepared[['Ticker', 'Date', 'Close', 'pos_score', 'Close_lag_1', 'Close_lag_10', 'target_close']].head())
# Out:
# Lagged features and target variable created successfully.
#        Ticker        Date    Close  pos_score  Close_lag_1  Close_lag_10  \
# 480  adanient  2023-01-16  3619.80   0.141085      3721.15       3841.20
# 528  adanient  2023-01-17  3639.35   0.123740      3619.80       3830.95
# 576  adanient  2023-01-18  3596.70   0.101935      3639.35       3827.05
# 624  adanient  2023-01-19  3463.55   0.072113      3596.70       3829.80
# 672  adanient  2023-01-20  3456.15   0.113261      3463.55       3824.25
#
#      target_close
# 480       3639.35
# 528       3596.70
# 576       3463.55
# 624       3456.15
# 672       3436.35

# %%
print(df_prepared.columns.tolist())
print(df_prepared.shape)
# Out:
# ['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'date', 'cleaned_news', 'cleaned_news_len', 'neg_score', 'neu_score', 'pos_score', 'ticker_enumerated', 'ticker_scaled', 'Close_lag_1', 'Close_lag_2', 'Close_lag_3', 'Close_lag_4', 'Close_lag_5', 'Close_lag_6', 'Close_lag_7', 'Close_lag_8', 'Close_lag_9', 'Close_lag_10', 'pos_score_lag_1', 'pos_score_lag_2', 'pos_score_lag_3', 'pos_score_lag_4', 'pos_score_lag_5', 'pos_score_lag_6', 'pos_score_lag_7', 'pos_score_lag_8', 'pos_score_lag_9', 'pos_score_lag_10', 'neg_score_lag_1', 'neg_score_lag_2', 'neg_score_lag_3', 'neg_score_lag_4', 'neg_score_lag_5', 'neg_score_lag_6', 'neg_score_lag_7', 'neg_score_lag_8', 'neg_score_lag_9', 'neg_score_lag_10', 'neu_score_lag_1', 'neu_score_lag_2', 'neu_score_lag_3', 'neu_score_lag_4', 'neu_score_lag_5', 'neu_score_lag_6', 'neu_score_lag_7', 'neu_score_lag_8', 'neu_score_lag_9', 'neu_score_lag_10', 'Open_lag_1', 'Open_lag_2', 'Open_lag_3', 'Open_lag_4', 'Open_lag_5', 'Open_lag_6', 'Open_lag_7', 'Open_lag_8', 'Open_lag_9', 'Open_lag_10', 'High_lag_1', 'High_lag_2', 'High_lag_3', 'High_lag_4', 'High_lag_5', 'High_lag_6', 'High_lag_7', 'High_lag_8', 'High_lag_9', 'High_lag_10', 'Low_lag_1', 'Low_lag_2', 'Low_lag_3', 'Low_lag_4', 'Low_lag_5', 'Low_lag_6', 'Low_lag_7', 'Low_lag_8', 'Low_lag_9', 'Low_lag_10', 'Volume_lag_1', 'Volume_lag_2', 'Volume_lag_3', 'Volume_lag_4', 'Volume_lag_5', 'Volume_lag_6', 'Volume_lag_7', 'Volume_lag_8', 'Volume_lag_9', 'Volume_lag_10', 'target_close']
# (37631, 97)

# %% [markdown]
# ### Data Splitting (Train, Validation, Test)
#
# Now we will split the data into training, validation, and test sets. Since this is time-series data, it's crucial to perform the split chronologically to avoid data leakage. We'll use an 80/10/10 ratio for train/validation/test.

# %%
import numpy as np

# Determine split points based on time
# First, convert 'Date' column to datetime objects if not already
df_prepared = df_prepared.copy() # Explicitly create a copy to avoid SettingWithCopyWarning
df_prepared['Date'] = pd.to_datetime(df_prepared['Date'])

# Get unique dates and sort them
dates = df_prepared['Date'].unique()
dates = np.sort(dates) # Fixed: Use np.sort for DatetimeArray

# Calculate split indices
total_samples = len(dates)
train_split_idx = int(total_samples * 0.8)
val_split_idx = int(total_samples * 0.9)

train_date_end = dates[train_split_idx - 1]
val_date_end = dates[val_split_idx - 1]

# Split the data chronologically
train_df = df_prepared[df_prepared['Date'] <= train_date_end]
val_df = df_prepared[(df_prepared['Date'] > train_date_end) & (df_prepared['Date'] <= val_date_end)]
test_df = df_prepared[df_prepared['Date'] > val_date_end]

print(f"Training data shape: {train_df.shape}")
print(f"Validation data shape: {val_df.shape}")
print(f"Test data shape: {test_df.shape}")

print("Data split into training, validation, and test sets successfully.")
# Out:
# Training data shape: (30005, 97)
# Validation data shape: (3779, 97)
# Test data shape: (3847, 97)
# Data split into training, validation, and test sets successfully.

# %%
# Define the features (X) and target (y)
feature_cols = [
    'Open', 'High', 'Low', 'Close', 'Volume',
    'neg_score', 'neu_score', 'pos_score',
    'ticker_scaled'
]

# Add all lagged features (lag 1 to 10 for each of the original features)
lag_features_base = ['Close', 'pos_score', 'neg_score', 'neu_score', 'Open', 'High', 'Low', 'Volume']
for base_feature in lag_features_base:
    for i in range(1, 11):
        feature_cols.append(f'{base_feature}_lag_{i}')

target_col = 'target_close'

# Prepare X and y for train, validation, and test sets
X_train = train_df[feature_cols].copy()
y_train = train_df[target_col].copy()

X_val = val_df[feature_cols].copy()
y_val = val_df[target_col].copy()

X_test = test_df[feature_cols].copy()
y_test = test_df[target_col].copy()

print("Feature and target sets created successfully.")
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# Feature and target sets created successfully.
# X_train shape: (30005, 89), y_train shape: (30005,)
# X_val shape: (3779, 89), y_val shape: (3779,)
# X_test shape: (3847, 89), y_test shape: (3847,)

# %%
from sklearn.preprocessing import MinMaxScaler

# Identify numerical columns to be scaled (excluding sentiments and ticker_scaled as they are already in range 0-1)
columns_to_scale = [
    'Open', 'High', 'Low', 'Close', 'Volume',
    'Close_lag_1', 'Close_lag_2', 'Close_lag_3', 'Close_lag_4', 'Close_lag_5', 'Close_lag_6', 'Close_lag_7', 'Close_lag_8', 'Close_lag_9', 'Close_lag_10',
    'Open_lag_1', 'Open_lag_2', 'Open_lag_3', 'Open_lag_4', 'Open_lag_5', 'Open_lag_6', 'Open_lag_7', 'Open_lag_8', 'Open_lag_9', 'Open_lag_10',
    'High_lag_1', 'High_lag_2', 'High_lag_3', 'High_lag_4', 'High_lag_5', 'High_lag_6', 'High_lag_7', 'High_lag_8', 'High_lag_9', 'High_lag_10',
    'Low_lag_1', 'Low_lag_2', 'Low_lag_3', 'Low_lag_4', 'Low_lag_5', 'Low_lag_6', 'Low_lag_7', 'Low_lag_8', 'Low_lag_9', 'Low_lag_10',
    'Volume_lag_1', 'Volume_lag_2', 'Volume_lag_3', 'Volume_lag_4', 'Volume_lag_5', 'Volume_lag_6', 'Volume_lag_7', 'Volume_lag_8', 'Volume_lag_9', 'Volume_lag_10'
]

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler on the training data for the specified columns and transform
X_train[columns_to_scale] = scaler.fit_transform(X_train[columns_to_scale])

# Transform the validation and test data using the scaler fitted on the training data
X_val[columns_to_scale] = scaler.transform(X_val[columns_to_scale])
X_test[columns_to_scale] = scaler.transform(X_test[columns_to_scale])

print("Selected numerical features scaled successfully to range 0-1.")
print("X_train (first 5 rows after scaling):")
display(X_train[columns_to_scale].head())
print("X_test (first 5 rows after scaling):")
display(X_test[columns_to_scale].head())
# Out:
# Selected numerical features scaled successfully to range 0-1.
# X_train (first 5 rows after scaling):
#          Open      High       Low     Close    Volume  Close_lag_1  \
# 480  0.275165  0.270800  0.268755  0.265666  0.003986     0.273202
# 528  0.267671  0.264172  0.265746  0.267120  0.003568     0.265666
# 576  0.269769  0.264055  0.263244  0.263948  0.007811     0.267120
# 624  0.256431  0.255963  0.255656  0.254048  0.007905     0.263948
# 672  0.254933  0.251536  0.256733  0.253498  0.003230     0.254048
#
#      Close_lag_2  Close_lag_3  Close_lag_4  Close_lag_5  ...  Volume_lag_1  \
# 480     0.267703     0.266856     0.267681     0.283177  ...      0.002919
# 528     0.273202     0.267703     0.266856     0.267681  ...      0.003986
# 576     0.265666     0.273202     0.267703     0.266856  ...      0.003568
# 624     0.267120     0.265666     0.273202     0.267703  ...      0.007811
# 672     0.263948     0.267120     0.265666     0.273202  ...      0.007905
#
#      Volume_lag_2  Volume_lag_3  Volume_lag_4  Volume_lag_5  Volume_lag_6  \
# 480      0.002566      0.004762      0.007690      0.001613      0.001951
# 528      0.002919      0.002566      0.004762      0.007690      0.001613
# 576      0.003986      0.002919      0.002566      0.004762      0.007690
# 624      0.003568      0.003986      0.002919      0.002566      0.004762
# 672      0.007811      0.003568      0.003986      0.002919      0.002566
#
#      Volume_lag_7  Volume_lag_8  Volume_lag_9  Volume_lag_10
# 480      0.002132      0.002199      0.001711       0.001974
# 528      0.001951      0.002132      0.002199       0.001711
# 576      0.001613      0.001951      0.002132       0.002199
# 624      0.007690      0.001613      0.001951       0.002132
# 672      0.004762      0.007690      0.001613       0.001951
#
# [5 rows x 55 columns]
# X_test (first 5 rows after scaling):
#            Open      High       Low     Close    Volume  Close_lag_1  \
# 34284  0.169377  0.166276  0.169879  0.167408  0.001235     0.172690
# 34334  0.168439  0.165629  0.168010  0.167127  0.001399     0.167408
# 34384  0.169602  0.175486  0.169659  0.175612  0.014748     0.167127
# 34434  0.178174  0.176019  0.177507  0.175878  0.005970     0.175612
# 34484  0.178029  0.178060  0.178452  0.177940  0.009919     0.175878
#
#        Close_lag_2  Close_lag_3  Close_lag_4  Close_lag_5  ...  Volume_lag_1  \
# 34284     0.168593     0.176438     0.179947     0.180988  ...      0.004775
# 34334     0.172690     0.168593     0.176438     0.179947  ...      0.001235
# 34384     0.167408     0.172690     0.168593     0.176438  ...      0.001399
# 34434     0.167127     0.167408     0.172690     0.168593  ...      0.014748
# 34484     0.175612     0.167127     0.167408     0.172690  ...      0.005970
#
#        Volume_lag_2  Volume_lag_3  Volume_lag_4  Volume_lag_5  Volume_lag_6  \
# 34284      0.004231      0.004433      0.001564      0.001815      0.001675
# 34334      0.004775      0.004231      0.004433      0.001564      0.001815
# 34384      0.001235      0.004775      0.004231      0.004433      0.001564
# 34434      0.001399      0.001235      0.004775      0.004231      0.004433
# 34484      0.014748      0.001399      0.001235      0.004775      0.004231
#
#        Volume_lag_7  Volume_lag_8  Volume_lag_9  Volume_lag_10
# 34284      0.003265      0.001341      0.001022       0.001013
# 34334      0.001675      0.003265      0.001341       0.001022
# 34384      0.001815      0.001675      0.003265       0.001341
# 34434      0.001564      0.001815      0.001675       0.003265
# 34484      0.004433      0.001564      0.001815       0.001675
#
# [5 rows x 55 columns]

# %% [markdown]
# ### LSTM Model Training
#
# To train an LSTM model, we first need to reshape our input data `X` into a 3D array: `(samples, timesteps, features_per_timestep)`.
#
# We have identified 8 time-varying features (`Close`, `pos_window`, `neg_window`, `neu_window`, `Open`, `High`, `Low`, `Volume`) and an 11-day window (current day + 10 lags). Thus, `timesteps` will be 11 and `features_per_timestep` will be 8. The `ticker_scaled` feature will be excluded from the sequential input for this initial model setup.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Define the base features that were lagged and will form our timesteps
features_base = ['Close', 'pos_score', 'neg_score', 'neu_score', 'Open', 'High', 'Low', 'Volume']
N_TIMESTEPS = 11  # Current day + 10 lagged days
N_FEATURES_PER_TIMESTEP = len(features_base)  # 8 features

# List to hold the reordered feature columns for LSTM input
lstm_feature_columns = []

# Add features from t-10 down to t-1 (lagged features)
for lag in range(10, 0, -1):
    for feature in features_base:
        lstm_feature_columns.append(f'{feature}_lag_{lag}')

# Add current day's features
for feature in features_base:
    lstm_feature_columns.append(feature)

# Select these specific columns from the X datasets and convert to numpy arrays
X_train_lstm = X_train[lstm_feature_columns].values
X_val_lstm   = X_val[lstm_feature_columns].values
X_test_lstm  = X_test[lstm_feature_columns].values

# Extract the 'ticker_scaled' feature separately
X_train_ticker = X_train['ticker_scaled'].values
X_val_ticker   = X_val['ticker_scaled'].values
X_test_ticker  = X_test['ticker_scaled'].values

# Reshape the data to (samples, timesteps, features_per_timestep)
X_train_reshaped = X_train_lstm.reshape((X_train_lstm.shape[0], N_TIMESTEPS, N_FEATURES_PER_TIMESTEP))
X_val_reshaped   = X_val_lstm.reshape((X_val_lstm.shape[0], N_TIMESTEPS, N_FEATURES_PER_TIMESTEP))
X_test_reshaped  = X_test_lstm.reshape((X_test_lstm.shape[0], N_TIMESTEPS, N_FEATURES_PER_TIMESTEP))

print("Data reshaped for LSTM model successfully.")
print(f"X_train_reshaped shape: {X_train_reshaped.shape}")
print(f"X_val_reshaped shape  : {X_val_reshaped.shape}")
print(f"X_test_reshaped shape : {X_test_reshaped.shape}")
# Out:
# Data reshaped for LSTM model successfully.
# X_train_reshaped shape: (30005, 11, 8)
# X_val_reshaped shape  : (3779, 11, 8)
# X_test_reshaped shape : (3847, 11, 8)

# %% [markdown]
# ### LSTM Model Definition

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Define the base features (including ticker_scaled as a static feature repeated across timesteps)
features_base = ['Close', 'pos_score', 'neg_score', 'neu_score', 'Open', 'High', 'Low', 'Volume', 'ticker_scaled']
N_TIMESTEPS = 11  # Current day + 10 lagged days
N_FEATURES_PER_TIMESTEP = len(features_base)  # 9 features

# List to hold the reordered feature columns for LSTM input
lstm_feature_columns = []

# Add features from t-10 down to t-1 (lagged features)
for lag in range(10, 0, -1):
    for feature in features_base:
        if feature == 'ticker_scaled':  # ticker_scaled has no lags; repeat the same column
            lstm_feature_columns.append(feature)
        else:
            lstm_feature_columns.append(f'{feature}_lag_{lag}')

# Add current day's features
for feature in features_base:
    lstm_feature_columns.append(feature)

# Select these specific columns from the X datasets and convert to numpy arrays
X_train_lstm = X_train[lstm_feature_columns].values
X_val_lstm   = X_val[lstm_feature_columns].values
X_test_lstm  = X_test[lstm_feature_columns].values

# Reshape the data to (samples, timesteps, features_per_timestep)
X_train_reshaped = X_train_lstm.reshape((X_train_lstm.shape[0], N_TIMESTEPS, N_FEATURES_PER_TIMESTEP))
X_val_reshaped   = X_val_lstm.reshape((X_val_lstm.shape[0], N_TIMESTEPS, N_FEATURES_PER_TIMESTEP))
X_test_reshaped  = X_test_lstm.reshape((X_test_lstm.shape[0], N_TIMESTEPS, N_FEATURES_PER_TIMESTEP))

print("Data reshaped for LSTM model successfully.")
print(f"X_train_reshaped shape: {X_train_reshaped.shape}")
print(f"X_val_reshaped shape  : {X_val_reshaped.shape}")
print(f"X_test_reshaped shape : {X_test_reshaped.shape}")
# Out:
# Data reshaped for LSTM model successfully.
# X_train_reshaped shape: (30005, 11, 9)
# X_val_reshaped shape  : (3779, 11, 9)
# X_test_reshaped shape : (3847, 11, 9)

# %%
import os, random
import numpy as np
import tensorflow as tf

# ── Reproducibility (must be set BEFORE building the model) ──
SEED = 32
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
print(f"Random seeds set to {SEED}")

# ── GPU memory growth (prevents TF from grabbing all 4 GB at once) ──
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"✓ {len(gpus)} GPU(s) detected: {[g.name for g in gpus]}")
    print(f"  TF version : {tf.__version__}")

    # Mixed precision: FP16 compute on Tensor Cores → ~2× throughput on RTX 3050
    tf.keras.mixed_precision.set_global_policy('mixed_float16')
    print("✓ Mixed precision policy: mixed_float16")
    BATCH_SIZE = 512   # large batch saturates GPU CUDA cores
else:
    print("⚠ No GPU found — running on CPU")
    BATCH_SIZE = 64

print(f"Batch size : {BATCH_SIZE}")
# Out:
# Random seeds set to 32
# ⚠ No GPU found — running on CPU
# Batch size : 64

# %% [markdown]
# ## Hyperparameter Tuning — Keras Tuner (Bayesian Optimization)
#
# **Why Bayesian Optimization?**
# - Builds a probabilistic surrogate model (Gaussian Process) of `val_loss` over the HP space
# - Each trial uses previous results to pick the *most promising* next HP set
# - Converges in ~20 trials vs hundreds needed by grid/random search
# - Combined with `EarlyStopping` (patience=5) during search → fast screening
#
# **Hyperparameters searched:**
# | HP | Range |
# |---|---|
# | `lstm_units_1` | 64 / 128 / 256 |
# | `lstm_units_2` | 32 / 64 / 128 |
# | `dropout_rate` | 0.1 → 0.5 |
# | `dense_units` | 16 / 32 / 64 |
# | `learning_rate` | 1e-4 → 1e-2 (log scale) |

# %%
import keras_tuner as kt
from tensorflow import keras
from tensorflow.keras import layers

# ══════════════════════════════════════════════════════════════════════
#  Step 1: Define the model-builder function
#  Keras Tuner calls this with different `hp` objects during search.
# ══════════════════════════════════════════════════════════════════════
def build_model(hp):
    # ── Hyperparameters to search ──
    lstm_units_1  = hp.Choice('lstm_units_1',  values=[64, 128, 256])
    lstm_units_2  = hp.Choice('lstm_units_2',  values=[32, 64, 128])
    dropout_rate  = hp.Float ('dropout_rate',  min_value=0.1, max_value=0.5, step=0.1)
    dense_units   = hp.Choice('dense_units',   values=[16, 32, 64])
    learning_rate = hp.Float ('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')

    # ── Architecture (same structure as final model) ──
    inputs = layers.Input(shape=(N_TIMESTEPS, N_FEATURES_PER_TIMESTEP), name='lstm_input')
    x = layers.LSTM(lstm_units_1, return_sequences=True, name='lstm_1')(inputs)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.LSTM(lstm_units_2, name='lstm_2')(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(dense_units, activation='relu')(x)
    outputs = layers.Dense(1, dtype='float32', name='output')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss='mse',
        metrics=['mae', 'root_mean_squared_error'],
    )
    return model


# ══════════════════════════════════════════════════════════════════════
#  Step 2: Configure the Bayesian Optimisation tuner
# ══════════════════════════════════════════════════════════════════════
tuner = kt.BayesianOptimization(
    hypermodel       = build_model,
    objective        = kt.Objective('val_loss', direction='min'),
    max_trials       = 20,          # number of HP combinations to try
    num_initial_points = 5,         # random exploration before Gaussian Process kicks in
    seed             = SEED,
    directory        = 'kt_tuning', # results are saved here
    project_name     = 'lstm_stock',
    overwrite        = True,        # set False to resume a previous search
)

tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 5
# lstm_units_1 (Choice)
# {'default': 64, 'conditions': [], 'values': [64, 128, 256], 'ordered': True}
# lstm_units_2 (Choice)
# {'default': 32, 'conditions': [], 'values': [32, 64, 128], 'ordered': True}
# dropout_rate (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# dense_units (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64], 'ordered': True}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %%
# ══════════════════════════════════════════════════════════════════════
#  Step 3: Run the HP search
#  Each trial trains for up to 30 epochs; EarlyStopping cuts short bad ones.
#  With 20 trials × ~10 effective epochs avg = ~200 epochs total.
#  Expected time on RTX 3050: ~5-10 minutes.
# ══════════════════════════════════════════════════════════════════════
search_callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=5, restore_best_weights=True
    ),
]

print("Starting Bayesian Optimisation search (20 trials) …")
tuner.search(
    train_ds,
    epochs            = 30,         # max epochs per trial (EarlyStopping cuts most short)
    validation_data   = val_ds,
    callbacks         = search_callbacks,
    verbose           = 1,
)

# ── Results ──
print("\n" + "="*60)
print("SEARCH COMPLETE — Best hyperparameters found:")
print("="*60)
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
for key, val in best_hp.values.items():
    print(f"  {key:20s} = {val}")
print("="*60)
# Out:
# Trial 20 Complete [00h 01m 50s]
# val_loss: 76923.28125
#
# Best val_loss So Far: 52386.8203125
# Total elapsed time: 00h 34m 51s
#
# ============================================================
# SEARCH COMPLETE — Best hyperparameters found:
# ============================================================
#   lstm_units_1         = 64
#   lstm_units_2         = 32
#   dropout_rate         = 0.30000000000000004
#   dense_units          = 64
#   learning_rate        = 0.0020998529871586384
# ============================================================

# %%
# ══════════════════════════════════════════════════════════════════════
#  Step 4: Build final model using best hyperparameters found by tuner
#  This replaces the static model definition below.
# ══════════════════════════════════════════════════════════════════════
model = tuner.hypermodel.build(best_hp)
model.summary()

print(f"\nFinal model built with best HP:")
print(f"  lstm_units_1  = {best_hp.get('lstm_units_1')}")
print(f"  lstm_units_2  = {best_hp.get('lstm_units_2')}")
print(f"  dropout_rate  = {best_hp.get('dropout_rate')}")
print(f"  dense_units   = {best_hp.get('dense_units')}")
print(f"  learning_rate = {best_hp.get('learning_rate'):.2e}")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_input (InputLayer)         │ (None, 11, 9)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 11, 64)         │        18,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,537 (131.00 KB)
#  Trainable params: 33,537 (131.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Final model built with best HP:
#   lstm_units_1  = 64
#   lstm_units_2  = 32
#   dropout_rate  = 0.30000000000000004
#   dense_units   = 64
#   learning_rate = 2.10e-03

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ── Collect all trial results into a DataFrame for inspection ──
rows = []
for trial in tuner.oracle.trials.values():
    if trial.score is not None:
        row = dict(trial.hyperparameters.values)
        row['val_loss'] = trial.score
        row['trial_id'] = trial.trial_id
        rows.append(row)

trials_df = pd.DataFrame(rows).sort_values('val_loss').reset_index(drop=True)
print("All trials ranked by val_loss (lower is better):")
display(trials_df)

# ── Bar chart: val_loss per trial ──
fig, ax = plt.subplots(figsize=(12, 4))
ax.bar(trials_df.index, trials_df['val_loss'], color=['green' if i == 0 else 'steelblue' for i in range(len(trials_df))])
ax.set_xlabel('Trial rank (0 = best)')
ax.set_ylabel('val_loss (MSE)')
ax.set_title('Bayesian HP Search — val_loss by trial')
ax.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# All trials ranked by val_loss (lower is better):
#     lstm_units_1  lstm_units_2  dropout_rate  dense_units  learning_rate  \
# 0             64            32           0.3           64       0.002100
# 1            128            32           0.2           32       0.002001
# 2             64            32           0.1           16       0.003388
# 3             64           128           0.1           64       0.001881
# 4             64            64           0.2           16       0.000975
# 5            256            32           0.1           16       0.001895
# 6             64            32           0.3           32       0.010000
# 7            128            32           0.1           64       0.010000
# 8             64            32           0.1           64       0.010000
# 9             64            64           0.2           16       0.000871
# 10           128            32           0.3           16       0.005978
# 11           128           128           0.1           16       0.000492
# 12           128            64           0.1           32       0.000307
# 13           256            64           0.3           32       0.000139
# 14            64            32           0.1           64       0.000114
# 15            64           128           0.1           16       0.000100
# 16           256           128           0.1           64       0.010000
# 17           256            64           0.5           16       0.008547
#
#         val_loss trial_id
# 0   5.238682e+04       09
# 1   7.692328e+04       19
# 2   8.060063e+04       08
# 3   1.161499e+05       11
# 4   1.234324e+05       05
# 5   1.322703e+05       14
# 6   1.326486e+05       13
# 7   1.359995e+05       10
# 8   1.365132e+05       17
# 9   1.375568e+05       07
# 10  2.353784e+05       02
# 11  2.858628e+05       15
# 12  5.021098e+05       03
# 13  3.232313e+06       06
# 14  6.197298e+06       12
# 15  8.108902e+06       18
# 16  9.111605e+06       16
# 17  9.162202e+06       04

# %%
# ── NOTE: The model is built above using the best HP from the Bayesian tuner.
# ── This static definition is kept only as a fallback if you skip the tuning cells.
# ── If you ran the tuner cells above, the `model` variable is already set — skip this cell.

# from tensorflow import keras
# from tensorflow.keras import layers
# lstm_input   = layers.Input(shape=(N_TIMESTEPS, N_FEATURES_PER_TIMESTEP), name='lstm_input')
# x            = layers.LSTM(units=128, return_sequences=True, name='lstm_1')(lstm_input)
# x            = layers.Dropout(0.2)(x)
# x            = layers.LSTM(units=64, name='lstm_2')(x)
# x            = layers.Dropout(0.2)(x)
# x            = layers.Dense(32, activation='relu')(x)
# output_layer = layers.Dense(units=1, dtype='float32', name='output')(x)
# model        = keras.Model(inputs=lstm_input, outputs=output_layer)
# model.summary()

print("Model already built from Bayesian HP search — skipping static definition.")
print(f"Model input shape : {model.input_shape}")
print(f"Model output shape: {model.output_shape}")
# Out:
# Model already built from Bayesian HP search — skipping static definition.
# Model input shape : (None, 11, 9)
# Model output shape: (None, 1)

# %% [markdown]
# ### Compile the LSTM Model

# %%
# Seeds were already set in the GPU/TF setup cell above (SEED=32).
# This cell is kept as a checkpoint to verify variables are still in scope.
print(f"SEED={SEED}, BATCH_SIZE={BATCH_SIZE}")
print(f"Training samples : {X_train_reshaped.shape[0]:,}")
print(f"Validation samples: {X_val_reshaped.shape[0]:,}")
print(f"Test samples     : {X_test_reshaped.shape[0]:,}")
# Out:
# SEED=32, BATCH_SIZE=64
# Training samples : 30,005
# Validation samples: 3,779
# Test samples     : 3,847

# %%
# Re-compile with the best learning rate from the tuner
# (tuner.hypermodel.build already compiles, but we re-compile for full metrics)
optimizer = tf.keras.optimizers.Adam(learning_rate=best_hp.get('learning_rate'))

model.compile(
    optimizer=optimizer,
    loss='mse',
    metrics=['mae', 'root_mean_squared_error', 'mean_absolute_percentage_error'],
)
print(f"Model re-compiled  |  lr = {best_hp.get('learning_rate'):.2e}")
# Out:
# Model re-compiled  |  lr = 2.10e-03

# %%
import os

# ── tf.data pipeline: prefetch keeps GPU fed while CPU prepares next batch ──
AUTOTUNE = tf.data.AUTOTUNE

train_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_train_reshaped, y_train.values.astype('float32')))
    .shuffle(buffer_size=len(X_train_reshaped), seed=SEED)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
val_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_val_reshaped, y_val.values.astype('float32')))
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

# ── Callbacks ──
os.makedirs('checkpoints', exist_ok=True)
callbacks = [
    # Stop early if val_loss doesn't improve for 15 epochs (saves time)
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=15, restore_best_weights=True, verbose=1
    ),
    # Halve LR when plateau detected → better convergence
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=7, min_lr=1e-6, verbose=1
    ),
    # Save best checkpoint to disk
    tf.keras.callbacks.ModelCheckpoint(
        filepath='checkpoints/best_lstm.keras',
        monitor='val_loss', save_best_only=True, verbose=0
    ),
]

# ── Train ──
history = model.fit(
    train_ds,
    epochs=120,
    validation_data=val_ds,
    callbacks=callbacks,
    verbose=1,
)
print("\n✓ Training complete.")
print(f"  Best val_loss : {min(history.history['val_loss']):.4f}")
print(f"  Epochs run    : {len(history.history['loss'])}")
# Out:
# Epoch 1/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 7610247.5000 - mae: 1626.1566 - mean_absolute_percentage_error: 117.8594 - root_mean_squared_error: 2758.6677 - val_loss: 9387033.0000 - val_mae: 1767.1223 - val_mean_absolute_percentage_error: 156.0481 - val_root_mean_squared_error: 3063.8264 - learning_rate: 0.0021
# Epoch 2/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3150999.2500 - mae: 739.5129 - mean_absolute_percentage_error: 45.2418 - root_mean_squared_error: 1775.1055 - val_loss: 3066637.2500 - val_mae: 497.4482 - val_mean_absolute_percentage_error: 7.6990 - val_root_mean_squared_error: 1751.1816 - learning_rate: 0.0021
# Epoch 3/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 731709.2500 - mae: 327.8950 - mean_absolute_percentage_error: 17.0386 - root_mean_squared_error: 855.4000 - val_loss: 1024925.7500 - val_mae: 248.5492 - val_mean_absolute_percentage_error: 5.9173 - val_root_mean_squared_error: 1012.3862 - learning_rate: 0.0021
# Epoch 4/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 237182.9062 - mae: 227.1218 - mean_absolute_percentage_error: 15.4520 - root_mean_squared_error: 487.0143 - val_loss: 493023.2812 - val_mae: 211.8005 - val_mean_absolute_percentage_error: 7.2755 - val_root_mean_squared_error: 702.1562 - learning_rate: 0.0021
# Epoch 5/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 157955.7656 - mae: 203.6521 - mean_absolute_percentage_error: 14.8207 - root_mean_squared_error: 397.4365 - val_loss: 313131.2188 - val_mae: 142.7501 - val_mean_absolute_percentage_error: 4.7905 - val_root_mean_squared_error: 559.5813 - learning_rate: 0.0021
# Epoch 6/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 142928.7031 - mae: 195.1335 - mean_absolute_percentage_error: 14.2800 - root_mean_squared_error: 378.0591 - val_loss: 265930.3438 - val_mae: 150.9366 - val_mean_absolute_percentage_error: 8.7359 - val_root_mean_squared_error: 515.6843 - learning_rate: 0.0021
# Epoch 7/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 139939.2188 - mae: 192.2314 - mean_absolute_percentage_error: 14.5527 - root_mean_squared_error: 374.0845 - val_loss: 222588.7031 - val_mae: 122.1237 - val_mean_absolute_percentage_error: 4.4956 - val_root_mean_squared_error: 471.7931 - learning_rate: 0.0021
# Epoch 8/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 135757.7969 - mae: 189.3330 - mean_absolute_percentage_error: 14.3889 - root_mean_squared_error: 368.4532 - val_loss: 197716.7656 - val_mae: 145.6067 - val_mean_absolute_percentage_error: 8.3854 - val_root_mean_squared_error: 444.6535 - learning_rate: 0.0021
# Epoch 9/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 126610.3203 - mae: 185.5390 - mean_absolute_percentage_error: 13.9292 - root_mean_squared_error: 355.8234 - val_loss: 192917.5781 - val_mae: 161.1937 - val_mean_absolute_percentage_error: 17.0204 - val_root_mean_squared_error: 439.2238 - learning_rate: 0.0021
# Epoch 10/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 123931.7031 - mae: 181.2832 - mean_absolute_percentage_error: 13.9076 - root_mean_squared_error: 352.0393 - val_loss: 168470.9531 - val_mae: 113.7922 - val_mean_absolute_percentage_error: 5.5036 - val_root_mean_squared_error: 410.4521 - learning_rate: 0.0021
# Epoch 11/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 130828.9375 - mae: 183.6961 - mean_absolute_percentage_error: 13.9280 - root_mean_squared_error: 361.7028 - val_loss: 145055.2031 - val_mae: 92.0172 - val_mean_absolute_percentage_error: 4.5408 - val_root_mean_squared_error: 380.8611 - learning_rate: 0.0021
# Epoch 12/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 123587.3750 - mae: 178.9275 - mean_absolute_percentage_error: 14.1207 - root_mean_squared_error: 351.5500 - val_loss: 145885.4062 - val_mae: 144.4050 - val_mean_absolute_percentage_error: 9.5375 - val_root_mean_squared_error: 381.9495 - learning_rate: 0.0021
# Epoch 13/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 120649.0859 - mae: 177.4683 - mean_absolute_percentage_error: 14.1489 - root_mean_squared_error: 347.3458 - val_loss: 141821.4531 - val_mae: 133.4532 - val_mean_absolute_percentage_error: 10.3773 - val_root_mean_squared_error: 376.5919 - learning_rate: 0.0021
# Epoch 14/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 118600.8125 - mae: 173.9486 - mean_absolute_percentage_error: 13.7207 - root_mean_squared_error: 344.3847 - val_loss: 129822.3438 - val_mae: 111.9473 - val_mean_absolute_percentage_error: 5.1023 - val_root_mean_squared_error: 360.3087 - learning_rate: 0.0021
# Epoch 15/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 116416.9688 - mae: 173.0450 - mean_absolute_percentage_error: 14.1073 - root_mean_squared_error: 341.1993 - val_loss: 124811.2812 - val_mae: 87.9816 - val_mean_absolute_percentage_error: 4.5786 - val_root_mean_squared_error: 353.2864 - learning_rate: 0.0021
# Epoch 16/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 115302.6172 - mae: 172.5807 - mean_absolute_percentage_error: 13.9216 - root_mean_squared_error: 339.5624 - val_loss: 121124.4297 - val_mae: 111.2290 - val_mean_absolute_percentage_error: 5.3547 - val_root_mean_squared_error: 348.0294 - learning_rate: 0.0021
# Epoch 17/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 118546.8828 - mae: 169.5016 - mean_absolute_percentage_error: 13.4419 - root_mean_squared_error: 344.3064 - val_loss: 114906.3438 - val_mae: 83.2631 - val_mean_absolute_percentage_error: 3.0545 - val_root_mean_squared_error: 338.9784 - learning_rate: 0.0021
# Epoch 18/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 113500.8750 - mae: 163.2379 - mean_absolute_percentage_error: 12.9158 - root_mean_squared_error: 336.8989 - val_loss: 120316.9062 - val_mae: 85.7538 - val_mean_absolute_percentage_error: 3.8142 - val_root_mean_squared_error: 346.8673 - learning_rate: 0.0021
# Epoch 19/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 111879.3828 - mae: 164.5925 - mean_absolute_percentage_error: 12.9149 - root_mean_squared_error: 334.4838 - val_loss: 130720.4453 - val_mae: 166.5269 - val_mean_absolute_percentage_error: 14.7630 - val_root_mean_squared_error: 361.5528 - learning_rate: 0.0021
# Epoch 20/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 106275.0938 - mae: 157.9722 - mean_absolute_percentage_error: 12.1336 - root_mean_squared_error: 325.9986 - val_loss: 107990.0781 - val_mae: 107.9975 - val_mean_absolute_percentage_error: 6.6249 - val_root_mean_squared_error: 328.6184 - learning_rate: 0.0021
# Epoch 21/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 112764.1484 - mae: 162.7760 - mean_absolute_percentage_error: 13.4586 - root_mean_squared_error: 335.8037 - val_loss: 106428.8438 - val_mae: 110.7878 - val_mean_absolute_percentage_error: 7.6016 - val_root_mean_squared_error: 326.2343 - learning_rate: 0.0021
# Epoch 22/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 105310.6719 - mae: 157.5980 - mean_absolute_percentage_error: 13.0948 - root_mean_squared_error: 324.5161 - val_loss: 128173.4609 - val_mae: 127.0366 - val_mean_absolute_percentage_error: 4.5199 - val_root_mean_squared_error: 358.0132 - learning_rate: 0.0021
# Epoch 23/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 104385.3359 - mae: 155.2227 - mean_absolute_percentage_error: 13.0642 - root_mean_squared_error: 323.0872 - val_loss: 101711.5312 - val_mae: 89.1047 - val_mean_absolute_percentage_error: 4.5474 - val_root_mean_squared_error: 318.9225 - learning_rate: 0.0021
# Epoch 24/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 100888.9531 - mae: 154.4113 - mean_absolute_percentage_error: 13.3655 - root_mean_squared_error: 317.6302 - val_loss: 102715.2891 - val_mae: 95.1166 - val_mean_absolute_percentage_error: 7.6510 - val_root_mean_squared_error: 320.4922 - learning_rate: 0.0021
# Epoch 25/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 98704.7188 - mae: 152.0276 - mean_absolute_percentage_error: 13.1529 - root_mean_squared_error: 314.1731 - val_loss: 102486.3906 - val_mae: 117.0338 - val_mean_absolute_percentage_error: 7.8124 - val_root_mean_squared_error: 320.1349 - learning_rate: 0.0021
# Epoch 26/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 98199.2422 - mae: 150.5302 - mean_absolute_percentage_error: 12.7093 - root_mean_squared_error: 313.3676 - val_loss: 100917.0078 - val_mae: 124.4223 - val_mean_absolute_percentage_error: 5.7784 - val_root_mean_squared_error: 317.6744 - learning_rate: 0.0021
# Epoch 27/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 99693.5547 - mae: 150.1046 - mean_absolute_percentage_error: 12.1337 - root_mean_squared_error: 315.7429 - val_loss: 81584.0234 - val_mae: 79.1177 - val_mean_absolute_percentage_error: 4.2037 - val_root_mean_squared_error: 285.6292 - learning_rate: 0.0021
# Epoch 28/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 91715.9141 - mae: 145.2110 - mean_absolute_percentage_error: 11.3876 - root_mean_squared_error: 302.8463 - val_loss: 87039.8359 - val_mae: 118.6364 - val_mean_absolute_percentage_error: 6.2929 - val_root_mean_squared_error: 295.0251 - learning_rate: 0.0021
# Epoch 29/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 94420.5078 - mae: 147.0106 - mean_absolute_percentage_error: 11.5528 - root_mean_squared_error: 307.2792 - val_loss: 84755.5703 - val_mae: 90.6948 - val_mean_absolute_percentage_error: 5.3211 - val_root_mean_squared_error: 291.1281 - learning_rate: 0.0021
# Epoch 30/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 94738.7266 - mae: 143.3808 - mean_absolute_percentage_error: 10.6710 - root_mean_squared_error: 307.7966 - val_loss: 70651.2812 - val_mae: 76.4293 - val_mean_absolute_percentage_error: 3.4807 - val_root_mean_squared_error: 265.8031 - learning_rate: 0.0021
# Epoch 31/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 92623.1484 - mae: 139.8008 - mean_absolute_percentage_error: 9.8460 - root_mean_squared_error: 304.3405 - val_loss: 84146.5469 - val_mae: 82.3105 - val_mean_absolute_percentage_error: 3.2703 - val_root_mean_squared_error: 290.0802 - learning_rate: 0.0021
# Epoch 32/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 91983.5547 - mae: 141.2427 - mean_absolute_percentage_error: 9.8283 - root_mean_squared_error: 303.2879 - val_loss: 70600.5078 - val_mae: 75.6338 - val_mean_absolute_percentage_error: 2.7793 - val_root_mean_squared_error: 265.7076 - learning_rate: 0.0021
# Epoch 33/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 83248.9531 - mae: 136.8711 - mean_absolute_percentage_error: 9.6740 - root_mean_squared_error: 288.5290 - val_loss: 96213.0938 - val_mae: 120.7234 - val_mean_absolute_percentage_error: 8.7717 - val_root_mean_squared_error: 310.1823 - learning_rate: 0.0021
# Epoch 34/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 92764.8984 - mae: 139.9960 - mean_absolute_percentage_error: 9.5970 - root_mean_squared_error: 304.5733 - val_loss: 62722.3906 - val_mae: 74.8005 - val_mean_absolute_percentage_error: 3.1230 - val_root_mean_squared_error: 250.4444 - learning_rate: 0.0021
# Epoch 35/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 84409.5781 - mae: 133.1542 - mean_absolute_percentage_error: 9.0977 - root_mean_squared_error: 290.5333 - val_loss: 67899.3672 - val_mae: 74.0541 - val_mean_absolute_percentage_error: 3.4035 - val_root_mean_squared_error: 260.5751 - learning_rate: 0.0021
# Epoch 36/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 79549.4375 - mae: 132.4942 - mean_absolute_percentage_error: 9.1953 - root_mean_squared_error: 282.0451 - val_loss: 77008.0234 - val_mae: 83.6047 - val_mean_absolute_percentage_error: 4.1824 - val_root_mean_squared_error: 277.5032 - learning_rate: 0.0021
# Epoch 37/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 81083.2578 - mae: 131.3769 - mean_absolute_percentage_error: 9.2631 - root_mean_squared_error: 284.7512 - val_loss: 87193.5000 - val_mae: 89.2707 - val_mean_absolute_percentage_error: 3.2579 - val_root_mean_squared_error: 295.2855 - learning_rate: 0.0021
# Epoch 38/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 78348.3281 - mae: 127.9482 - mean_absolute_percentage_error: 8.7799 - root_mean_squared_error: 279.9077 - val_loss: 65282.9297 - val_mae: 75.9285 - val_mean_absolute_percentage_error: 3.5038 - val_root_mean_squared_error: 255.5052 - learning_rate: 0.0021
# Epoch 39/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 77553.2266 - mae: 127.0690 - mean_absolute_percentage_error: 8.8450 - root_mean_squared_error: 278.4838 - val_loss: 49007.2383 - val_mae: 82.2488 - val_mean_absolute_percentage_error: 4.0035 - val_root_mean_squared_error: 221.3758 - learning_rate: 0.0021
# Epoch 40/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 76730.0469 - mae: 126.5284 - mean_absolute_percentage_error: 8.8614 - root_mean_squared_error: 277.0019 - val_loss: 57774.6914 - val_mae: 86.3079 - val_mean_absolute_percentage_error: 4.2858 - val_root_mean_squared_error: 240.3637 - learning_rate: 0.0021
# Epoch 41/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 75868.3438 - mae: 125.0038 - mean_absolute_percentage_error: 8.7582 - root_mean_squared_error: 275.4421 - val_loss: 82679.9844 - val_mae: 109.5165 - val_mean_absolute_percentage_error: 5.1935 - val_root_mean_squared_error: 287.5413 - learning_rate: 0.0021
# Epoch 42/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 74031.7812 - mae: 124.4704 - mean_absolute_percentage_error: 8.8685 - root_mean_squared_error: 272.0878 - val_loss: 85058.3203 - val_mae: 81.4562 - val_mean_absolute_percentage_error: 3.3393 - val_root_mean_squared_error: 291.6476 - learning_rate: 0.0021
# Epoch 43/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 76026.3438 - mae: 125.6893 - mean_absolute_percentage_error: 9.1144 - root_mean_squared_error: 275.7288 - val_loss: 63272.5742 - val_mae: 77.4275 - val_mean_absolute_percentage_error: 2.9259 - val_root_mean_squared_error: 251.5404 - learning_rate: 0.0021
# Epoch 44/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 71838.7344 - mae: 123.9689 - mean_absolute_percentage_error: 9.0010 - root_mean_squared_error: 268.0275 - val_loss: 67917.3984 - val_mae: 98.9402 - val_mean_absolute_percentage_error: 5.7918 - val_root_mean_squared_error: 260.6097 - learning_rate: 0.0021
# Epoch 45/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 73767.3906 - mae: 123.7310 - mean_absolute_percentage_error: 8.9438 - root_mean_squared_error: 271.6015 - val_loss: 64484.3203 - val_mae: 76.6047 - val_mean_absolute_percentage_error: 3.0885 - val_root_mean_squared_error: 253.9376 - learning_rate: 0.0021
# Epoch 46/120
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72924.7636 - mae: 122.2845 - mean_absolute_percentage_error: 8.8083 - root_mean_squared_error: 269.9711
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0010499265044927597.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 70961.4766 - mae: 121.1658 - mean_absolute_percentage_error: 8.8651 - root_mean_squared_error: 266.3860 - val_loss: 51662.2734 - val_mae: 69.6893 - val_mean_absolute_percentage_error: 4.4572 - val_root_mean_squared_error: 227.2934 - learning_rate: 0.0021
# Epoch 47/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 66604.7344 - mae: 116.8414 - mean_absolute_percentage_error: 8.4382 - root_mean_squared_error: 258.0789 - val_loss: 51413.5234 - val_mae: 71.0167 - val_mean_absolute_percentage_error: 2.8348 - val_root_mean_squared_error: 226.7455 - learning_rate: 0.0010
# Epoch 48/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 63920.2539 - mae: 114.6812 - mean_absolute_percentage_error: 8.3308 - root_mean_squared_error: 252.8246 - val_loss: 65294.1836 - val_mae: 77.5568 - val_mean_absolute_percentage_error: 3.2306 - val_root_mean_squared_error: 255.5273 - learning_rate: 0.0010
# Epoch 49/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 66394.7734 - mae: 116.7461 - mean_absolute_percentage_error: 8.5937 - root_mean_squared_error: 257.6718 - val_loss: 42349.3125 - val_mae: 70.8688 - val_mean_absolute_percentage_error: 3.1217 - val_root_mean_squared_error: 205.7895 - learning_rate: 0.0010
# Epoch 50/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 65463.5938 - mae: 115.8796 - mean_absolute_percentage_error: 8.5874 - root_mean_squared_error: 255.8585 - val_loss: 40782.7578 - val_mae: 61.1597 - val_mean_absolute_percentage_error: 2.8281 - val_root_mean_squared_error: 201.9474 - learning_rate: 0.0010
# Epoch 51/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 61474.1562 - mae: 113.1819 - mean_absolute_percentage_error: 8.4215 - root_mean_squared_error: 247.9398 - val_loss: 52451.3008 - val_mae: 77.8712 - val_mean_absolute_percentage_error: 3.0133 - val_root_mean_squared_error: 229.0225 - learning_rate: 0.0010
# Epoch 52/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 62314.0508 - mae: 113.0145 - mean_absolute_percentage_error: 8.5823 - root_mean_squared_error: 249.6278 - val_loss: 45059.3711 - val_mae: 77.9317 - val_mean_absolute_percentage_error: 5.0487 - val_root_mean_squared_error: 212.2719 - learning_rate: 0.0010
# Epoch 53/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 59516.9141 - mae: 110.8795 - mean_absolute_percentage_error: 8.5118 - root_mean_squared_error: 243.9609 - val_loss: 38820.2734 - val_mae: 64.1214 - val_mean_absolute_percentage_error: 4.2197 - val_root_mean_squared_error: 197.0286 - learning_rate: 0.0010
# Epoch 54/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 61269.3320 - mae: 111.8689 - mean_absolute_percentage_error: 8.5163 - root_mean_squared_error: 247.5264 - val_loss: 40981.4062 - val_mae: 72.1068 - val_mean_absolute_percentage_error: 4.9459 - val_root_mean_squared_error: 202.4386 - learning_rate: 0.0010
# Epoch 55/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 59902.8867 - mae: 110.3619 - mean_absolute_percentage_error: 8.5719 - root_mean_squared_error: 244.7507 - val_loss: 51032.2344 - val_mae: 73.9079 - val_mean_absolute_percentage_error: 2.8848 - val_root_mean_squared_error: 225.9032 - learning_rate: 0.0010
# Epoch 56/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 59535.6562 - mae: 109.8730 - mean_absolute_percentage_error: 8.4330 - root_mean_squared_error: 243.9993 - val_loss: 38315.7422 - val_mae: 72.7389 - val_mean_absolute_percentage_error: 3.6977 - val_root_mean_squared_error: 195.7441 - learning_rate: 0.0010
# Epoch 57/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 59332.6367 - mae: 110.0330 - mean_absolute_percentage_error: 8.6093 - root_mean_squared_error: 243.5829 - val_loss: 30959.3867 - val_mae: 63.1765 - val_mean_absolute_percentage_error: 3.3779 - val_root_mean_squared_error: 175.9528 - learning_rate: 0.0010
# Epoch 58/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 55939.0508 - mae: 109.1917 - mean_absolute_percentage_error: 8.7085 - root_mean_squared_error: 236.5144 - val_loss: 36974.5898 - val_mae: 62.8776 - val_mean_absolute_percentage_error: 3.4950 - val_root_mean_squared_error: 192.2878 - learning_rate: 0.0010
# Epoch 59/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 55343.1250 - mae: 107.6209 - mean_absolute_percentage_error: 8.6175 - root_mean_squared_error: 235.2512 - val_loss: 32775.3438 - val_mae: 65.3198 - val_mean_absolute_percentage_error: 3.1041 - val_root_mean_squared_error: 181.0396 - learning_rate: 0.0010
# Epoch 60/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 52105.0898 - mae: 106.5933 - mean_absolute_percentage_error: 8.6416 - root_mean_squared_error: 228.2654 - val_loss: 50213.1445 - val_mae: 70.1718 - val_mean_absolute_percentage_error: 3.0989 - val_root_mean_squared_error: 224.0829 - learning_rate: 0.0010
# Epoch 61/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 55375.0352 - mae: 107.1372 - mean_absolute_percentage_error: 8.7264 - root_mean_squared_error: 235.3190 - val_loss: 36055.4102 - val_mae: 67.7929 - val_mean_absolute_percentage_error: 4.6897 - val_root_mean_squared_error: 189.8826 - learning_rate: 0.0010
# Epoch 62/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 58393.0664 - mae: 109.5052 - mean_absolute_percentage_error: 8.7597 - root_mean_squared_error: 241.6466 - val_loss: 24961.8320 - val_mae: 60.6500 - val_mean_absolute_percentage_error: 3.5614 - val_root_mean_squared_error: 157.9931 - learning_rate: 0.0010
# Epoch 63/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 55516.3086 - mae: 107.3662 - mean_absolute_percentage_error: 8.8294 - root_mean_squared_error: 235.6190 - val_loss: 30632.5527 - val_mae: 60.2562 - val_mean_absolute_percentage_error: 2.7356 - val_root_mean_squared_error: 175.0216 - learning_rate: 0.0010
# Epoch 64/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 55813.3398 - mae: 106.8157 - mean_absolute_percentage_error: 8.7427 - root_mean_squared_error: 236.2485 - val_loss: 32953.3164 - val_mae: 65.0170 - val_mean_absolute_percentage_error: 4.1045 - val_root_mean_squared_error: 181.5305 - learning_rate: 0.0010
# Epoch 65/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 55957.5781 - mae: 107.6343 - mean_absolute_percentage_error: 8.7655 - root_mean_squared_error: 236.5535 - val_loss: 23186.3711 - val_mae: 59.3013 - val_mean_absolute_percentage_error: 3.2726 - val_root_mean_squared_error: 152.2707 - learning_rate: 0.0010
# Epoch 66/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 53908.8086 - mae: 105.9193 - mean_absolute_percentage_error: 8.8771 - root_mean_squared_error: 232.1827 - val_loss: 25200.6641 - val_mae: 59.3418 - val_mean_absolute_percentage_error: 3.8075 - val_root_mean_squared_error: 158.7472 - learning_rate: 0.0010
# Epoch 67/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 51543.7852 - mae: 105.2892 - mean_absolute_percentage_error: 8.8188 - root_mean_squared_error: 227.0326 - val_loss: 21458.2441 - val_mae: 57.6757 - val_mean_absolute_percentage_error: 3.2220 - val_root_mean_squared_error: 146.4863 - learning_rate: 0.0010
# Epoch 68/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 52271.2578 - mae: 105.2150 - mean_absolute_percentage_error: 8.8921 - root_mean_squared_error: 228.6291 - val_loss: 31743.7461 - val_mae: 58.3825 - val_mean_absolute_percentage_error: 2.7543 - val_root_mean_squared_error: 178.1677 - learning_rate: 0.0010
# Epoch 69/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 53611.9805 - mae: 106.0042 - mean_absolute_percentage_error: 8.8647 - root_mean_squared_error: 231.5426 - val_loss: 26248.6250 - val_mae: 57.8611 - val_mean_absolute_percentage_error: 2.7641 - val_root_mean_squared_error: 162.0143 - learning_rate: 0.0010
# Epoch 70/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 50981.0664 - mae: 103.8695 - mean_absolute_percentage_error: 8.8479 - root_mean_squared_error: 225.7899 - val_loss: 41277.9922 - val_mae: 82.3407 - val_mean_absolute_percentage_error: 3.0692 - val_root_mean_squared_error: 203.1699 - learning_rate: 0.0010
# Epoch 71/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 53643.8906 - mae: 105.5670 - mean_absolute_percentage_error: 8.7778 - root_mean_squared_error: 231.6115 - val_loss: 22460.0059 - val_mae: 65.0166 - val_mean_absolute_percentage_error: 3.7528 - val_root_mean_squared_error: 149.8666 - learning_rate: 0.0010
# Epoch 72/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 52063.1055 - mae: 104.9549 - mean_absolute_percentage_error: 8.9368 - root_mean_squared_error: 228.1734 - val_loss: 15641.0850 - val_mae: 54.8805 - val_mean_absolute_percentage_error: 2.6612 - val_root_mean_squared_error: 125.0643 - learning_rate: 0.0010
# Epoch 73/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 50109.2852 - mae: 104.3670 - mean_absolute_percentage_error: 8.9971 - root_mean_squared_error: 223.8510 - val_loss: 35284.5430 - val_mae: 68.7601 - val_mean_absolute_percentage_error: 2.7377 - val_root_mean_squared_error: 187.8418 - learning_rate: 0.0010
# Epoch 74/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 52049.7617 - mae: 105.0206 - mean_absolute_percentage_error: 8.9492 - root_mean_squared_error: 228.1442 - val_loss: 17407.8496 - val_mae: 54.1298 - val_mean_absolute_percentage_error: 2.7078 - val_root_mean_squared_error: 131.9388 - learning_rate: 0.0010
# Epoch 75/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 47434.3867 - mae: 101.9262 - mean_absolute_percentage_error: 8.8650 - root_mean_squared_error: 217.7944 - val_loss: 22262.9805 - val_mae: 52.6323 - val_mean_absolute_percentage_error: 2.5540 - val_root_mean_squared_error: 149.2078 - learning_rate: 0.0010
# Epoch 76/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 47257.4492 - mae: 102.6234 - mean_absolute_percentage_error: 9.0105 - root_mean_squared_error: 217.3878 - val_loss: 19654.6992 - val_mae: 55.2380 - val_mean_absolute_percentage_error: 2.6979 - val_root_mean_squared_error: 140.1952 - learning_rate: 0.0010
# Epoch 77/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 49846.1094 - mae: 103.7307 - mean_absolute_percentage_error: 8.9102 - root_mean_squared_error: 223.2624 - val_loss: 19219.5645 - val_mae: 56.6939 - val_mean_absolute_percentage_error: 3.7346 - val_root_mean_squared_error: 138.6346 - learning_rate: 0.0010
# Epoch 78/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 46310.6016 - mae: 102.4235 - mean_absolute_percentage_error: 8.9714 - root_mean_squared_error: 215.1990 - val_loss: 25397.6426 - val_mae: 64.2118 - val_mean_absolute_percentage_error: 3.0062 - val_root_mean_squared_error: 159.3664 - learning_rate: 0.0010
# Epoch 79/120
# 459/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46009.9085 - mae: 101.9927 - mean_absolute_percentage_error: 9.1535 - root_mean_squared_error: 214.4222
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0005249632522463799.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 47371.5977 - mae: 102.2783 - mean_absolute_percentage_error: 9.1318 - root_mean_squared_error: 217.6502 - val_loss: 23494.0488 - val_mae: 63.4890 - val_mean_absolute_percentage_error: 5.3824 - val_root_mean_squared_error: 153.2777 - learning_rate: 0.0010
# Epoch 80/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 44903.9062 - mae: 100.1926 - mean_absolute_percentage_error: 8.6856 - root_mean_squared_error: 211.9054 - val_loss: 12026.8252 - val_mae: 55.6401 - val_mean_absolute_percentage_error: 3.0125 - val_root_mean_squared_error: 109.6669 - learning_rate: 5.2496e-04
# Epoch 81/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 45069.7930 - mae: 100.5963 - mean_absolute_percentage_error: 8.7978 - root_mean_squared_error: 212.2965 - val_loss: 13744.7305 - val_mae: 50.7496 - val_mean_absolute_percentage_error: 2.5532 - val_root_mean_squared_error: 117.2379 - learning_rate: 5.2496e-04
# Epoch 82/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 44462.7031 - mae: 100.0353 - mean_absolute_percentage_error: 8.8351 - root_mean_squared_error: 210.8618 - val_loss: 11182.8779 - val_mae: 48.3008 - val_mean_absolute_percentage_error: 3.2057 - val_root_mean_squared_error: 105.7491 - learning_rate: 5.2496e-04
# Epoch 83/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 44446.1758 - mae: 100.0183 - mean_absolute_percentage_error: 8.7312 - root_mean_squared_error: 210.8226 - val_loss: 26263.8223 - val_mae: 61.5285 - val_mean_absolute_percentage_error: 2.6824 - val_root_mean_squared_error: 162.0612 - learning_rate: 5.2496e-04
# Epoch 84/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 47500.7500 - mae: 101.7577 - mean_absolute_percentage_error: 8.9944 - root_mean_squared_error: 217.9467 - val_loss: 14933.9854 - val_mae: 52.6525 - val_mean_absolute_percentage_error: 2.9517 - val_root_mean_squared_error: 122.2047 - learning_rate: 5.2496e-04
# Epoch 85/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 43454.4922 - mae: 99.2034 - mean_absolute_percentage_error: 8.7957 - root_mean_squared_error: 208.4574 - val_loss: 19583.0117 - val_mae: 56.1975 - val_mean_absolute_percentage_error: 2.5602 - val_root_mean_squared_error: 139.9393 - learning_rate: 5.2496e-04
# Epoch 86/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 47390.2383 - mae: 101.3173 - mean_absolute_percentage_error: 8.8051 - root_mean_squared_error: 217.6930 - val_loss: 8922.5723 - val_mae: 45.4098 - val_mean_absolute_percentage_error: 2.7322 - val_root_mean_squared_error: 94.4594 - learning_rate: 5.2496e-04
# Epoch 87/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 44949.9570 - mae: 99.6078 - mean_absolute_percentage_error: 8.7669 - root_mean_squared_error: 212.0141 - val_loss: 13068.4521 - val_mae: 50.2453 - val_mean_absolute_percentage_error: 2.7012 - val_root_mean_squared_error: 114.3173 - learning_rate: 5.2496e-04
# Epoch 88/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 46072.3086 - mae: 100.9922 - mean_absolute_percentage_error: 8.9956 - root_mean_squared_error: 214.6446 - val_loss: 10142.4688 - val_mae: 44.7258 - val_mean_absolute_percentage_error: 3.2190 - val_root_mean_squared_error: 100.7098 - learning_rate: 5.2496e-04
# Epoch 89/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 43496.5547 - mae: 99.4643 - mean_absolute_percentage_error: 9.0946 - root_mean_squared_error: 208.5583 - val_loss: 12974.4473 - val_mae: 43.0795 - val_mean_absolute_percentage_error: 2.2169 - val_root_mean_squared_error: 113.9054 - learning_rate: 5.2496e-04
# Epoch 90/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 44314.6289 - mae: 99.6771 - mean_absolute_percentage_error: 8.9231 - root_mean_squared_error: 210.5104 - val_loss: 17485.9414 - val_mae: 50.8812 - val_mean_absolute_percentage_error: 2.4172 - val_root_mean_squared_error: 132.2344 - learning_rate: 5.2496e-04
# Epoch 91/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41577.8086 - mae: 98.4541 - mean_absolute_percentage_error: 8.8831 - root_mean_squared_error: 203.9064 - val_loss: 10488.5820 - val_mae: 45.7121 - val_mean_absolute_percentage_error: 3.3073 - val_root_mean_squared_error: 102.4138 - learning_rate: 5.2496e-04
# Epoch 92/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41921.1484 - mae: 98.9558 - mean_absolute_percentage_error: 8.8775 - root_mean_squared_error: 204.7466 - val_loss: 13000.1465 - val_mae: 50.5290 - val_mean_absolute_percentage_error: 2.5122 - val_root_mean_squared_error: 114.0182 - learning_rate: 5.2496e-04
# Epoch 93/120
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42484.7951 - mae: 98.7829 - mean_absolute_percentage_error: 9.0806 - root_mean_squared_error: 205.9590
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0002624816261231899.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 45325.9414 - mae: 100.1461 - mean_absolute_percentage_error: 9.0048 - root_mean_squared_error: 212.8989 - val_loss: 11422.0771 - val_mae: 50.0263 - val_mean_absolute_percentage_error: 2.4040 - val_root_mean_squared_error: 106.8741 - learning_rate: 5.2496e-04
# Epoch 94/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 44468.9102 - mae: 99.1177 - mean_absolute_percentage_error: 8.8938 - root_mean_squared_error: 210.8765 - val_loss: 12650.0469 - val_mae: 46.6471 - val_mean_absolute_percentage_error: 2.6335 - val_root_mean_squared_error: 112.4724 - learning_rate: 2.6248e-04
# Epoch 95/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 43461.1797 - mae: 98.8568 - mean_absolute_percentage_error: 8.8918 - root_mean_squared_error: 208.4734 - val_loss: 9610.6758 - val_mae: 45.1704 - val_mean_absolute_percentage_error: 2.4798 - val_root_mean_squared_error: 98.0341 - learning_rate: 2.6248e-04
# Epoch 96/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41676.7617 - mae: 97.3505 - mean_absolute_percentage_error: 8.7070 - root_mean_squared_error: 204.1489 - val_loss: 12051.3350 - val_mae: 44.9992 - val_mean_absolute_percentage_error: 2.4652 - val_root_mean_squared_error: 109.7786 - learning_rate: 2.6248e-04
# Epoch 97/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 40019.9961 - mae: 96.4175 - mean_absolute_percentage_error: 8.7872 - root_mean_squared_error: 200.0500 - val_loss: 12191.7822 - val_mae: 48.0900 - val_mean_absolute_percentage_error: 2.5813 - val_root_mean_squared_error: 110.4164 - learning_rate: 2.6248e-04
# Epoch 98/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 42517.4922 - mae: 97.7528 - mean_absolute_percentage_error: 8.8206 - root_mean_squared_error: 206.1977 - val_loss: 15153.6836 - val_mae: 51.5823 - val_mean_absolute_percentage_error: 2.2931 - val_root_mean_squared_error: 123.1003 - learning_rate: 2.6248e-04
# Epoch 99/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 44091.9844 - mae: 98.7443 - mean_absolute_percentage_error: 9.0920 - root_mean_squared_error: 209.9809 - val_loss: 10007.0752 - val_mae: 42.4595 - val_mean_absolute_percentage_error: 2.3643 - val_root_mean_squared_error: 100.0354 - learning_rate: 2.6248e-04
# Epoch 100/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41343.2383 - mae: 97.3264 - mean_absolute_percentage_error: 8.7207 - root_mean_squared_error: 203.3304 - val_loss: 7773.4771 - val_mae: 47.5358 - val_mean_absolute_percentage_error: 2.5894 - val_root_mean_squared_error: 88.1673 - learning_rate: 2.6248e-04
# Epoch 101/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41722.6602 - mae: 97.9703 - mean_absolute_percentage_error: 8.9005 - root_mean_squared_error: 204.2613 - val_loss: 8158.4683 - val_mae: 41.1214 - val_mean_absolute_percentage_error: 2.5962 - val_root_mean_squared_error: 90.3242 - learning_rate: 2.6248e-04
# Epoch 102/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 42364.7539 - mae: 97.3228 - mean_absolute_percentage_error: 8.7830 - root_mean_squared_error: 205.8270 - val_loss: 12048.9443 - val_mae: 47.5253 - val_mean_absolute_percentage_error: 2.4290 - val_root_mean_squared_error: 109.7677 - learning_rate: 2.6248e-04
# Epoch 103/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 42085.8828 - mae: 98.3948 - mean_absolute_percentage_error: 8.9158 - root_mean_squared_error: 205.1484 - val_loss: 15886.0293 - val_mae: 49.7357 - val_mean_absolute_percentage_error: 2.5424 - val_root_mean_squared_error: 126.0398 - learning_rate: 2.6248e-04
# Epoch 104/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 40873.8164 - mae: 97.5383 - mean_absolute_percentage_error: 8.8601 - root_mean_squared_error: 202.1727 - val_loss: 14157.9014 - val_mae: 48.3085 - val_mean_absolute_percentage_error: 2.1678 - val_root_mean_squared_error: 118.9870 - learning_rate: 2.6248e-04
# Epoch 105/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41412.9414 - mae: 97.0972 - mean_absolute_percentage_error: 8.9272 - root_mean_squared_error: 203.5017 - val_loss: 12067.0156 - val_mae: 46.6574 - val_mean_absolute_percentage_error: 2.3907 - val_root_mean_squared_error: 109.8500 - learning_rate: 2.6248e-04
# Epoch 106/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41140.1719 - mae: 96.7336 - mean_absolute_percentage_error: 8.6648 - root_mean_squared_error: 202.8304 - val_loss: 9725.3242 - val_mae: 40.8258 - val_mean_absolute_percentage_error: 2.2704 - val_root_mean_squared_error: 98.6171 - learning_rate: 2.6248e-04
# Epoch 107/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41737.0156 - mae: 98.0859 - mean_absolute_percentage_error: 8.8673 - root_mean_squared_error: 204.2964 - val_loss: 6481.5698 - val_mae: 38.4697 - val_mean_absolute_percentage_error: 2.1021 - val_root_mean_squared_error: 80.5082 - learning_rate: 2.6248e-04
# Epoch 108/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 39537.3984 - mae: 96.1477 - mean_absolute_percentage_error: 8.9036 - root_mean_squared_error: 198.8401 - val_loss: 10219.1719 - val_mae: 46.4995 - val_mean_absolute_percentage_error: 2.4242 - val_root_mean_squared_error: 101.0899 - learning_rate: 2.6248e-04
# Epoch 109/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 40209.8711 - mae: 97.5405 - mean_absolute_percentage_error: 8.7652 - root_mean_squared_error: 200.5240 - val_loss: 16563.4492 - val_mae: 49.0370 - val_mean_absolute_percentage_error: 2.2023 - val_root_mean_squared_error: 128.6991 - learning_rate: 2.6248e-04
# Epoch 110/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 40544.7305 - mae: 97.5137 - mean_absolute_percentage_error: 9.2277 - root_mean_squared_error: 201.3572 - val_loss: 7032.3765 - val_mae: 40.8451 - val_mean_absolute_percentage_error: 2.5677 - val_root_mean_squared_error: 83.8593 - learning_rate: 2.6248e-04
# Epoch 111/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41627.0391 - mae: 97.2895 - mean_absolute_percentage_error: 8.7364 - root_mean_squared_error: 204.0271 - val_loss: 9487.1377 - val_mae: 45.3035 - val_mean_absolute_percentage_error: 2.4483 - val_root_mean_squared_error: 97.4019 - learning_rate: 2.6248e-04
# Epoch 112/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41680.2344 - mae: 97.4023 - mean_absolute_percentage_error: 8.8101 - root_mean_squared_error: 204.1574 - val_loss: 6103.8145 - val_mae: 41.5889 - val_mean_absolute_percentage_error: 3.2333 - val_root_mean_squared_error: 78.1269 - learning_rate: 2.6248e-04
# Epoch 113/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 40037.8203 - mae: 96.3002 - mean_absolute_percentage_error: 8.7587 - root_mean_squared_error: 200.0945 - val_loss: 9220.1689 - val_mae: 46.6752 - val_mean_absolute_percentage_error: 3.5335 - val_root_mean_squared_error: 96.0217 - learning_rate: 2.6248e-04
# Epoch 114/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 40101.7969 - mae: 97.3937 - mean_absolute_percentage_error: 8.8554 - root_mean_squared_error: 200.2543 - val_loss: 7528.6196 - val_mae: 42.7942 - val_mean_absolute_percentage_error: 2.4124 - val_root_mean_squared_error: 86.7676 - learning_rate: 2.6248e-04
# Epoch 115/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 38340.6914 - mae: 95.5715 - mean_absolute_percentage_error: 8.8376 - root_mean_squared_error: 195.8078 - val_loss: 9238.8027 - val_mae: 46.2366 - val_mean_absolute_percentage_error: 3.4459 - val_root_mean_squared_error: 96.1187 - learning_rate: 2.6248e-04
# Epoch 116/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 38648.2461 - mae: 96.2087 - mean_absolute_percentage_error: 8.8284 - root_mean_squared_error: 196.5916 - val_loss: 13255.7041 - val_mae: 49.1904 - val_mean_absolute_percentage_error: 2.7065 - val_root_mean_squared_error: 115.1334 - learning_rate: 2.6248e-04
# Epoch 117/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 40068.1836 - mae: 96.2866 - mean_absolute_percentage_error: 8.6652 - root_mean_squared_error: 200.1704 - val_loss: 12019.0283 - val_mae: 46.0337 - val_mean_absolute_percentage_error: 2.1700 - val_root_mean_squared_error: 109.6313 - learning_rate: 2.6248e-04
# Epoch 118/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 38823.5352 - mae: 96.0446 - mean_absolute_percentage_error: 8.8930 - root_mean_squared_error: 197.0369 - val_loss: 8872.0459 - val_mae: 41.9262 - val_mean_absolute_percentage_error: 2.5786 - val_root_mean_squared_error: 94.1915 - learning_rate: 2.6248e-04
# Epoch 119/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41601.3945 - mae: 97.0097 - mean_absolute_percentage_error: 8.7302 - root_mean_squared_error: 203.9333
# Epoch 119: ReduceLROnPlateau reducing learning rate to 0.00013124081306159496.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 40720.7148 - mae: 96.5382 - mean_absolute_percentage_error: 8.6934 - root_mean_squared_error: 201.7937 - val_loss: 8640.4932 - val_mae: 41.8005 - val_mean_absolute_percentage_error: 2.0896 - val_root_mean_squared_error: 92.9543 - learning_rate: 2.6248e-04
# Epoch 120/120
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 37729.2031 - mae: 95.0136 - mean_absolute_percentage_error: 8.7696 - root_mean_squared_error: 194.2401 - val_loss: 10644.4463 - val_mae: 41.8787 - val_mean_absolute_percentage_error: 2.2364 - val_root_mean_squared_error: 103.1719 - learning_rate: 1.3124e-04
# Restoring model weights from the end of the best epoch: 112.
#
# ✓ Training complete.
#   Best val_loss : 6103.8145
#   Epochs run    : 120

# %%
# Evaluate the model on the test set
loss, mae, rmse, mape = model.evaluate(X_test_reshaped, y_test, verbose=0)

print(f"Test Loss (MSE): {loss}")
print(f"Test MAE: {mae}")
print(f"Test RMSE: {rmse}")
print(f"Test MAPE: {mape}")
# Out:
# Test Loss (MSE): 7346.6416015625
# Test MAE: 43.70371627807617
# Test RMSE: 85.71255493164062
# Test MAPE: 3.280238389968872

# %%
# Make predictions on the test set
predictions = model.predict(X_test_reshaped)

# Reshape y_test for plotting if it's a Series
y_test_np = y_test.values.reshape(-1, 1)

print("Predictions made successfully.")
print(f"Predictions shape: {predictions.shape}")
print(f"Actual values shape: {y_test_np.shape}")
# Out:
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Predictions made successfully.
# Predictions shape: (3847, 1)
# Actual values shape: (3847, 1)

# %%
import matplotlib.pyplot as plt

# Create a DataFrame for easier plotting
plot_df = pd.DataFrame({
    'Actual Close': y_test_np.flatten(),
    'Predicted Close': predictions.flatten()
})

plt.figure(figsize=(15, 7))
plt.plot(plot_df['Actual Close'], label='Actual Close Price')
plt.plot(plot_df['Predicted Close'], label='Predicted Close Price', alpha=0.7)
plt.title('LSTM Model: Actual vs. Predicted Close Prices on Test Set')
plt.xlabel('Time Step (implicit)')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
display(plot_df.head(10))
# Out:
#    Actual Close  Predicted Close
# 0       2294.58      2339.378418
# 1       2408.69      2311.608643
# 2       2412.27      2323.073975
# 3       2440.00      2388.449463
# 4       2462.00      2399.836182
# 5       2436.80      2391.553955
# 6       2433.10      2396.061279
# 7       2446.10      2389.271729
# 8       2422.30      2386.399658
# 9       2399.20      2394.362061

# %%
model.save('lstm_stock_predictor_norm_2lstm_tsip.keras')
print("Trained model saved as 'lstm_stock_predictor.keras'")
# Out:
# Trained model saved as 'lstm_stock_predictor.keras'

# %%
import matplotlib.pyplot as plt
import pandas as pd

# To inverse transform 'Close_lag_1', we need the full 'columns_to_scale' context from X_test
# First, ensure X_test is a DataFrame (it already is)

# Create a temporary DataFrame with all scaled columns that were used for fitting the scaler
temp_X_test_scaled_for_inverse = X_test[columns_to_scale]

# Inverse transform these columns. This will return a numpy array in the original scale.
original_scale_features = scaler.inverse_transform(temp_X_test_scaled_for_inverse)

# Convert back to DataFrame to easily select the 'Close_lag_1' column, preserving index for potential merges
original_scale_features_df = pd.DataFrame(original_scale_features, columns=columns_to_scale, index=X_test.index)

# Now, extract the inverse-transformed 'Close_lag_1'
inverse_transformed_close_lag_1 = original_scale_features_df['Close'].values.flatten()

# Combine the relevant data into a single DataFrame for plotting
combined_plot_df = pd.DataFrame({
    'Actual Close': y_test_np.flatten(),
    'Predicted Close': predictions.flatten(),
    'Close_lag_1': inverse_transformed_close_lag_1
})

plt.figure(figsize=(18, 8))
plt.plot(combined_plot_df['Actual Close'], label='Actual Close Price', color='blue', linewidth=2)
plt.plot(combined_plot_df['Predicted Close'], label='Predicted Close Price', color='red', linestyle='--', alpha=0.7)
plt.plot(combined_plot_df['Close_lag_1'], label='Previous Day Close (Close_lag_1)', color='green', linestyle=':', alpha=0.7)
plt.title('LSTM Model: Actual vs. Predicted vs. Previous Day Close Prices on Test Set')
plt.xlabel('Time Step (implicit)')
plt.ylabel('Price')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

display(combined_plot_df.head())
# Out:
#    Actual Close  Predicted Close  Close_lag_1
# 0       2294.58      2339.378418      2298.36
# 1       2408.69      2311.608643      2294.58
# 2       2412.27      2323.073975      2408.69
# 3       2440.00      2388.449463      2412.27
# 4       2462.00      2399.836182      2440.00
